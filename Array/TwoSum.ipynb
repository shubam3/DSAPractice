# %%
# enumerate(nums) provides both index (i) and value (num) in nums.
# range(n) → Generates indices from 0 to n-1, allowing us to loop through the list.
# Using range(len(nums)) ensures we can access both index (i) and value (nums[i]).

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        n = len(nums)

        for i in range(n):
            for j in range(i+1,n):
                if nums[i]+nums[j]==target:
                 return [i,j]

# %% [markdown]
# This solution uses a brute-force approach to solve the Two Sum problem. I iterate through the array using one loop, and for each element at index i, I use a second loop to check every element after it (j = i + 1 onward). For each pair, I check whether their sum equals the target. If it does, I immediately return their indices. This approach ensures that all possible pairs are checked exactly once. The time complexity is O(n²) due to the nested loops, and the space complexity is O(1) since no extra data structures are used.

# %%
def twoSum(nums,target):  
 prevMap = {} #val : index

 for i,n in enumerate(nums):
            diff = target-n
            if diff in prevMap:
                return[prevMap[diff],i]
            prevMap[n] = i

# %% [markdown]
# This solution uses an optimized approach with a hash map (dictionary) to solve the Two Sum problem in one pass. As I iterate through the array using enumerate, I calculate the difference between the target and the current number. Then, I check whether this difference already exists in the dictionary, which stores previously seen numbers and their indices. If it exists, that means we have found the two numbers that add up to the target, so I return their indices. If not, I store the current number and its index in the dictionary for future reference. This approach reduces the time complexity to O(n) because each element is processed once, and the space complexity is O(n) due to the extra dictionary used for lookups.
