# %%
#  Time Complexity: O(n)
# Reason:
# Move fast pointer n steps → O(n)
# Then move both fast and slow to the end → at most O(n)

# → Total: O(n)
# Space Complexity: O(1)
# No extra space used (just pointers)

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def removeNthFromEnd(head, n):
    # Step 1: Create dummy node
    dummy = ListNode(0, head)
    slow = fast = dummy

    # Step 2: Move fast ahead by n steps
    for _ in range(n):
        fast = fast.next

    # Step 3: Move both until fast reaches the end
    while fast.next:
        fast = fast.next
        slow = slow.next

    # Step 4: Remove the node
    slow.next = slow.next.next

    # Return the updated list
    return dummy.next

# %% [markdown]
# This solution removes the Nth node from the end of a linked list using the two-pointer technique. First, we create a dummy node that points to the head to handle edge cases like removing the first node. We initialize both slow and fast pointers at the dummy. Then, we move the fast pointer n steps ahead to create a gap of n nodes between slow and fast. After that, we move both pointers forward together until the fast pointer reaches the end of the list. At that point, the slow pointer will be just before the node that needs to be removed. We then skip that node by updating slow.next. This approach runs in O(n) time with O(1) extra space.
