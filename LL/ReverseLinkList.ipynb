# %%
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:   
     prev_node = None
     curr_node = head  # Use 'head' directly

     while curr_node:  # Loop until we reach the end of the list
            next_node = curr_node.next  # Store next node
            curr_node.next = prev_node  # Reverse the pointer
            prev_node = curr_node  # Move prev_node forward
            curr_node = next_node  # Move curr_node forward

     return prev_node  # Return new head (previously the last node)

# %% [markdown]
# This solution reverses a singly linked list using an iterative approach with three pointers. We maintain prev_node, curr_node, and next_node. Initially, prev_node is set to None and curr_node starts at the head. In each iteration, we first store the next node so we don’t lose the remaining list. Then we reverse the current node’s pointer by making it point to prev_node. After reversing the link, we move prev_node one step forward to the current node, and move curr_node to the saved next node. This process continues until we reach the end of the list. At that point, prev_node will be the new head of the reversed list, which we return. The time complexity is O(n) since we traverse the list once, and the space complexity is O(1) because we use only constant extra space.

# %%
def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
    # Base case
    if not head or not head.next:
        return head

    # Reverse the rest of the list
    new_head = self.reverseList(head.next)

    # Reverse current connection
    head.next.next = head
    head.next = None

    return new_head



# Go to the last node using recursion.

# While returning back (backtracking), reverse the links.

# head.next.next = head → makes the next node point back to current.

# head.next = None → break original forward link.

# Return new_head (original last node).
